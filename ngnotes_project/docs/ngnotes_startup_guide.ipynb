# %% [markdown]
# # NGNotes Startup Notebook (macOS)
# Use the code cells below as copy-paste terminal commands in VS Code.

# %% [markdown]
# ## 1) Backend Setup + Start (Apple Silicon Mac)

# %%
# Copy this line into VS Code terminal (Apple Silicon)
cmd = "cd /Users/stamilselvan7/Project/NGNotes/ngnotes_project/backend && /opt/homebrew/bin/python3.11 -m venv .venv && source .venv/bin/activate && python -m pip install --upgrade pip setuptools wheel && pip install -r requirements.txt && cp -n .env.example .env && python -m uvicorn app.main:app --host 127.0.0.1 --port 8010 --reload --log-level debug"
print(cmd)

# %% [markdown]
# ## 2) Backend Setup + Start (Intel Mac)

# %%
# Copy this line into VS Code terminal (Intel)
cmd = "cd /Users/stamilselvan7/Project/NGNotes/ngnotes_project/backend && /usr/local/bin/python3.11 -m venv .venv && source .venv/bin/activate && python -m pip install --upgrade pip setuptools wheel && pip install -r requirements.txt && cp -n .env.example .env && python -m uvicorn app.main:app --host 127.0.0.1 --port 8010 --reload --log-level debug"
print(cmd)

# %% [markdown]
# ## 3) Health Check (run in a second terminal)

# %%
cmd = "curl -sS http://127.0.0.1:8010/api/health"
print(cmd)

# %% [markdown]
# ## 4) Frontend Start (run in another terminal tab)

# %%
cmd = "cd /Users/stamilselvan7/Project/NGNotes/ngnotes_project/frontend && python3 serve.py"
print(cmd)

# %% [markdown]
# ## 5) Ollama (optional, if missing)

# %%
cmd = "brew install ollama && brew services start ollama"
print(cmd)
